# %%
import pandas as pd

# %%
df = pd.read_pickle("../ascensor1.pkl")
df
# Out:
#                       box  width  height   id gender   age  position_x  \
# 0    [888, 236, 935, 294]   47.0    58.0  1.0      M  54.0       911.5
# 1    [908, 237, 954, 292]   46.0    55.0  1.0      M  37.0       931.0
# 2    [928, 234, 982, 296]   54.0    62.0  1.0      F  47.0       955.0
# 3    [937, 241, 988, 304]   51.0    63.0  1.0      M  53.0       962.5
# 4   [952, 239, 1000, 317]   48.0    78.0  1.0      F  43.0       976.0
# 5    [933, 247, 995, 324]   62.0    77.0  1.0      F  45.0       964.0
# 6    [913, 255, 972, 332]   59.0    77.0  1.0      F  43.0       942.5
# 7    [896, 265, 952, 340]   56.0    75.0  1.0      F  46.0       924.0
# 8    [883, 278, 942, 353]   59.0    75.0  1.0      F  33.0       912.5
# 9    [854, 287, 913, 364]   59.0    77.0  1.0      M  39.0       883.5
# 10   [824, 294, 885, 372]   61.0    78.0  1.0      M  42.0       854.5
# 11   [784, 296, 844, 372]   60.0    76.0  1.0      M  51.0       814.0
# ...

# %%
df.dtypes
# Out:
# box                object
# width             float64
# height            float64
# id                float64
# gender             object
# age               float64
# position_x        float64
# position_y        float64
# last_pos_time     float64
# confidence        float32
# embedding_norm    float32
# dtype: object

# %%
dfID = df.groupby([id]).count()
print(dfID.head())
# Out:
#          box  width  height  id  gender  age  position_x  position_y  \
# 9788960    1      1       1   1       1    1           1           1
# 9788992    1      1       1   1       1    1           1           1
# 9789024    1      1       1   1       1    1           1           1
# 9789056    1      1       1   1       1    1           1           1
# 9789088    1      1       1   1       1    1           1           1
# 9789120    1      1       1   1       1    1           1           1
# 9789152    1      1       1   1       1    1           1           1
# 9789184    1      1       1   1       1    1           1           1
# 9789216    1      1       1   1       1    1           1           1
# 9789248    1      1       1   1       1    1           1           1
# 9789280    1      1       1   1       1    1           1           1
# 9789312    1      1       1   1       1    1           1           1
# 9789344    1      1       1   1       1    1           1           1
# ...
